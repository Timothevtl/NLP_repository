# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (3.8.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: click in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk) (8.1.3)
# Requirement already satisfied: tqdm in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: joblib in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: colorama in c:\users\timot\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click->nltk) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\timot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')
text=" Hello everyone. Hope all are fine and doing well. Hope you find the book interesting"
tokenizer.tokenize(text)
# Out:
# [' Hello everyone.',
#  'Hope all are fine and doing well.',
#  'Hope you find the book interesting']

# %%
french_tokenizer=nltk.data.load('tokenizers/punkt/french.pickle')

# %%
with open('extrait_ukraine_20min.txt', 'r', encoding='utf-8') as file:
    file_contents1 = file.read()

text_list1 = [file_contents1]

# %%
with open('extrait_prof_tué_ladepeche.txt', 'r', encoding='utf-8') as file:
    file_contents2 = file.read()

text_list2 = [file_contents2]

# %%
with open('extrait_ukraine_lemonde.txt', 'r', encoding='utf-8') as file:
    file_contents3 = file.read()

text_list3 = [file_contents3]

# %%
for article1 in text_list1:
    article1 = article1.replace('\n', '. ')
for article2 in text_list2:
    article2 = article2.replace('\n', '. ')
for article3 in text_list3:
    article3 = article3.replace('\n', '. ')
article1_tokenisé_phrases = french_tokenizer.tokenize(article1)
article2_tokenisé_phrases = french_tokenizer.tokenize(article2)
article3_tokenisé_phrases = french_tokenizer.tokenize(article3)

# %%
article1_tokenisé_phrases
# Out:
# ['Vous avez manqué les infos de ce début de matinée ?',
#  'On vous a concocté un récap pour vous aider à y voir plus clair.. .',
#  'Zelensky aux Etats-Unis pour s’adresser à l’ONU et rencontrer Biden.',
#  'Alors qu’il avait dû, il y a un an, s’exprimer virtuellement devant les Nations unies, Volodymyr Zelensky est cette fois venu à New York.',
#  'Il est arrivé lundi, avant son discours attendu ce mardi à la tribune de l’Assemblée générale de l’ONU.. .',
#  'Le président ukrainien participera également mercredi à un Conseil de sécurité de l’Organisation consacré à la guerre avec la Russie.',
#  'Pour la première fois depuis le début du conflit en Ukraine, il devrait donc se retrouver à la même table que le ministre russe des Affaires étrangères Sergueï Lavrov.',
#  'Il se rendra enfin jeudi à Washington pour une visite à la Maison-Blanche pour parler aide militaire et financière.. .',
#  'Devant les recteurs, Attal exige un « électrochoc » sur le harcèlement scolaire.',
#  'Le ministre de l’Education nationale a décidé d’accélérer sur la lutte contre le harcèlement scolaire.',
#  'Alors que la polémique enfle sur l’attitude du rectorat vis-à-vis des parents de Nicolas, l’adolescent de Poissy (Yvelines) qui s’est suicidé à la rentrée, Gabriel Attal a exigé lundi un « électrochoc à tous les niveaux ».',
#  'Et pour faire passer le message, le ministre a réuni exceptionnellement les recteurs.. .',
#  '« Mon rôle, votre rôle, n’est pas de protéger une Institution à tout prix, mais de protéger à tout prix nos élèves, nos enfants », a-t-il déclaré selon des propos rapportés par son entourage.',
#  'Un audit sur la gestion des cas de harcèlement de septembre 2022 à septembre 2023 va en outre être lancé dans chaque académie.',
#  'Les conclusions sont attendues dans quatre semaines.. .',
#  'Darmanin à Rome pour vanter la « fermeté » face à l’afflux de migrants.',
#  'La crise migratoire est une nouvelle fois au cœur des discussions entre la France et l’Italie.',
#  'Le ministre de l’Intérieur Gérald Darmanin est arrivé lundi soir à Rome, où il prévoit de délivrer un message de « fermeté » face aux traversées clandestines de la Méditerranée, après l’afflux de migrants sur l’île italienne de Lampedusa.. .',
#  'Le ministre est arrivé peu avant 19h30 au ministère de l’Intérieur italien pour y rencontrer son homologue Matteo Piantedosi.',
#  'Gérald Darmanin compte proposer l’aide de la France à l’Italie pour « tenir sa frontière extérieure », première porte d’entrée vers l’Europe en provenance d’Afrique du Nord, a-t-il déclaré sur les médias Europe 1/Cnews.. .',
#  'SOCIÉTÉ.',
#  'Bientôt un centre pour migrants à Menton ?',
#  '« Nous allons armer des espaces en plus pour la PAF », rectifie le préfet.',
#  'POLITIQUE.',
#  'Migrants à Lampedusa : « Il faut qu’on s’y mette tous » pour les accueillir, estime Mélenchon']

# %%
from nltk.tokenize import TreebankWordTokenizer
word_tokenizer = TreebankWordTokenizer()

# %%
article1_words = []
article1_words
article1_words
for i in article1_tokenisé_phrases:
    a = word_tokenizer.tokenize(i)
    article1_words.append(a)

# %%
article1_words
# Out:
# [['Vous',
#   'avez',
#   'manqué',
#   'les',
#   'infos',
#   'de',
#   'ce',
#   'début',
#   'de',
#   'matinée',
#   '?'],
#  ['On',
#   'vous',
#   'a',
#   'concocté',
#   'un',
#   'récap',
#   'pour',
#   'vous',
#   'aider',
#   'à',
#   'y',
#   'voir',
#   'plus',
#   'clair..',
#   '.'],
#  ['Zelensky',
#   'aux',
#   'Etats-Unis',
#   'pour',
#   's’adresser',
#   'à',
#   'l’ONU',
#   'et',
#   'rencontrer',
#   'Biden',
#   '.'],
#  ['Alors',
#   'qu’il',
#   'avait',
#   'dû',
#   ',',
#   'il',
#   'y',
#   'a',
#   'un',
#   'an',
#   ',',
#   's’exprimer',
#   'virtuellement',
#   'devant',
#   'les',
#   'Nations',
#   'unies',
#   ',',
#   'Volodymyr',
#   'Zelensky',
#   'est',
#   'cette',
#   'fois',
#   'venu',
#   'à',
#   'New',
#   'York',
#   '.'],
#  ['Il',
#   'est',
#   'arrivé',
#   'lundi',
#   ',',
#   'avant',
#   'son',
#   'discours',
#   'attendu',
#   'ce',
#   'mardi',
#   'à',
#   'la',
#   'tribune',
#   'de',
#   'l’Assemblée',
#   'générale',
#   'de',
#   'l’ONU..',
#   '.'],
#  ['Le',
#   'président',
#   'ukrainien',
#   'participera',
#   'également',
#   'mercredi',
#   'à',
#   'un',
#   'Conseil',
#   'de',
#   'sécurité',
#   'de',
#   'l’Organisation',
#   'consacré',
#   'à',
#   'la',
#   'guerre',
#   'avec',
#   'la',
#   'Russie',
#   '.'],
#  ['Pour',
#   'la',
#   'première',
#   'fois',
#   'depuis',
#   'le',
#   'début',
#   'du',
#   'conflit',
#   'en',
#   'Ukraine',
#   ',',
#   'il',
#   'devrait',
#   'donc',
#   'se',
#   'retrouver',
#   'à',
#   'la',
#   'même',
#   'table',
#   'que',
#   'le',
#   'ministre',
#   'russe',
#   'des',
#   'Affaires',
#   'étrangères',
#   'Sergueï',
#   'Lavrov',
#   '.'],
#  ['Il',
#   'se',
#   'rendra',
#   'enfin',
#   'jeudi',
#   'à',
#   'Washington',
#   'pour',
#   'une',
#   'visite',
#   'à',
#   'la',
#   'Maison-Blanche',
#   'pour',
#   'parler',
#   'aide',
#   'militaire',
#   'et',
#   'financière..',
#   '.'],
#  ['Devant',
#   'les',
#   'recteurs',
#   ',',
#   'Attal',
#   'exige',
#   'un',
#   '«',
#   'électrochoc',
#   '»',
#   'sur',
#   'le',
#   'harcèlement',
#   'scolaire',
#   '.'],
#  ['Le',
#   'ministre',
#   'de',
#   'l’Education',
#   'nationale',
#   'a',
#   'décidé',
#   'd’accélérer',
#   'sur',
#   'la',
#   'lutte',
#   'contre',
#   'le',
#   'harcèlement',
#   'scolaire',
#   '.'],
#  ['Alors',
#   'que',
#   'la',
#   'polémique',
#   'enfle',
#   'sur',
#   'l’attitude',
#   'du',
#   'rectorat',
#   'vis-à-vis',
#   'des',
#   'parents',
#   'de',
#   'Nicolas',
#   ',',
#   'l’adolescent',
#   'de',
#   'Poissy',
#   '(',
#   'Yvelines',
#   ')',
#   'qui',
#   's’est',
#   'suicidé',
#   'à',
#   'la',
#   'rentrée',
#   ',',
#   'Gabriel',
#   'Attal',
#   'a',
#   'exigé',
#   'lundi',
#   'un',
#   '«',
#   'électrochoc',
#   'à',
#   'tous',
#   'les',
#   'niveaux',
#   '»',
#   '.'],
#  ['Et',
#   'pour',
#   'faire',
#   'passer',
#   'le',
#   'message',
#   ',',
#   'le',
#   'ministre',
#   'a',
#   'réuni',
#   'exceptionnellement',
#   'les',
#   'recteurs..',
#   '.'],
#  ['«',
#   'Mon',
#   'rôle',
#   ',',
#   'votre',
#   'rôle',
#   ',',
#   'n’est',
#   'pas',
#   'de',
#   'protéger',
#   'une',
#   'Institution',
#   'à',
#   'tout',
#   'prix',
#   ',',
#   'mais',
#   'de',
#   'protéger',
#   'à',
#   'tout',
#   'prix',
#   'nos',
#   'élèves',
#   ',',
#   'nos',
#   'enfants',
#   '»',
#   ',',
#   'a-t-il',
#   'déclaré',
#   'selon',
#   'des',
#   'propos',
#   'rapportés',
#   'par',
#   'son',
#   'entourage',
#   '.'],
#  ['Un',
#   'audit',
#   'sur',
#   'la',
#   'gestion',
#   'des',
#   'cas',
#   'de',
#   'harcèlement',
#   'de',
#   'septembre',
#   '2022',
#   'à',
#   'septembre',
#   '2023',
#   'va',
#   'en',
#   'outre',
#   'être',
#   'lancé',
#   'dans',
#   'chaque',
#   'académie',
#   '.'],
#  ['Les',
#   'conclusions',
#   'sont',
#   'attendues',
#   'dans',
#   'quatre',
#   'semaines..',
#   '.'],
#  ['Darmanin',
#   'à',
#   'Rome',
#   'pour',
#   'vanter',
#   'la',
#   '«',
#   'fermeté',
#   '»',
#   'face',
#   'à',
#   'l’afflux',
#   'de',
#   'migrants',
#   '.'],
#  ['La',
#   'crise',
#   'migratoire',
#   'est',
#   'une',
#   'nouvelle',
#   'fois',
#   'au',
#   'cœur',
#   'des',
#   'discussions',
#   'entre',
#   'la',
#   'France',
#   'et',
#   'l’Italie',
#   '.'],
#  ['Le',
#   'ministre',
#   'de',
#   'l’Intérieur',
#   'Gérald',
#   'Darmanin',
#   'est',
#   'arrivé',
#   'lundi',
#   'soir',
#   'à',
#   'Rome',
#   ',',
#   'où',
#   'il',
#   'prévoit',
#   'de',
#   'délivrer',
#   'un',
#   'message',
#   'de',
#   '«',
#   'fermeté',
#   '»',
#   'face',
#   'aux',
#   'traversées',
#   'clandestines',
#   'de',
#   'la',
#   'Méditerranée',
#   ',',
#   'après',
#   'l’afflux',
#   'de',
#   'migrants',
#   'sur',
#   'l’île',
#   'italienne',
#   'de',
#   'Lampedusa..',
#   '.'],
#  ['Le',
#   'ministre',
#   'est',
#   'arrivé',
#   'peu',
#   'avant',
#   '19h30',
#   'au',
#   'ministère',
#   'de',
#   'l’Intérieur',
#   'italien',
#   'pour',
#   'y',
#   'rencontrer',
#   'son',
#   'homologue',
#   'Matteo',
#   'Piantedosi',
#   '.'],
#  ['Gérald',
#   'Darmanin',
#   'compte',
#   'proposer',
#   'l’aide',
#   'de',
#   'la',
#   'France',
#   'à',
#   'l’Italie',
#   'pour',
#   '«',
#   'tenir',
#   'sa',
#   'frontière',
#   'extérieure',
#   '»',
#   ',',
#   'première',
#   'porte',
#   'd’entrée',
#   'vers',
#   'l’Europe',
#   'en',
#   'provenance',
#   'd’Afrique',
#   'du',
#   'Nord',
#   ',',
#   'a-t-il',
#   'déclaré',
#   'sur',
#   'les',
#   'médias',
#   'Europe',
#   '1/Cnews..',
#   '.'],
#  ['SOCIÉTÉ', '.'],
#  ['Bientôt', 'un', 'centre', 'pour', 'migrants', 'à', 'Menton', '?'],
#  ['«',
#   'Nous',
#   'allons',
#   'armer',
#   'des',
#   'espaces',
#   'en',
#   'plus',
#   'pour',
#   'la',
#   'PAF',
#   '»',
#   ',',
#   'rectifie',
#   'le',
#   'préfet',
#   '.'],
#  ['POLITIQUE', '.'],
#  ['Migrants',
#   'à',
#   'Lampedusa',
#   ':',
#   '«',
#   'Il',
#   'faut',
#   'qu’on',
#   's’y',
#   'mette',
#   'tous',
#   '»',
#   'pour',
#   'les',
#   'accueillir',
#   ',',
#   'estime',
#   'Mélenchon']]

# %% [markdown]
# Unfortunately with this method we have the special characters seperated as words, which we don't want.
# Thus, I think regex is more appropriate.

# %% [markdown]
# Regex Method :

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer("[\w]+")
